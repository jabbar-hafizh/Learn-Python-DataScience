# %%
list1 = ["aaa","bbb"]
list2 = ["aaa","bbb"]
list3 = []

if list1 == list1 and list1 == list2:
  print(list1[::True])
# Out:
# ['aaa', 'bbb']

# %%
thisdict = {
  "brand": {"model": "Mustang","year": 1964}
}

print('{0}{1}'.format())

# %%
y = print(float('45'))
type(y)
# Out:
# 45.0
# NoneType

# %%
def a(**x):
  return type(x)

a(a='a', b=True)
# Out:
# dict

# %%
sum([50, True//1, -24, 200*False, 100, True*175])
# Out:
# 302

# %%
A = dict(zip(('s','a','d'),(1,2,3)))
A1 = sorted([A[a] for a in A])
# A2 = dict(A+A1)
print(A1)
# Out:
# [[1, 2, 3]]

# %%
jualan = ['bakso', 'mie ayam', 'kwetiau', 'pangsit', 'sop buah']

def abang():
  jualan.pop(3)
  return jualan

def tukang():
  jualan.append ('sop buah')
  return jualan

def bakso():
  jualan.extend (['kwetiau'])
  return jualan

def mari():
  jualan [0:1]

def sini():
  jualan. insert (10, 'bakso')

abang()
jualan = abang()*2
print(jualan)
print(jualan.count('bakso'))
# Out:
# ['bakso', 'mie ayam', 'kwetiau', 'bakso', 'mie ayam', 'kwetiau']
# 2

# %%
B = []
for a in A:
  if len(a)%2 != 0:
    if a[5]=='a':
      if a[-6]=='g':
        B.append(a)

C =
# Out:
#   File "<ipython-input-44-168b6bea3932>", line 8
#     C =
#         ^
# SyntaxError: invalid syntax
